# %% [markdown]
# # Feed-forward Neural Networks with Sequential and Functional Keras

# %% [markdown]
# ## Imports

# %%
from utilities.std_imports import *
import tensorflow.keras as tk

# %% [markdown]
# ## Load data

# %%
(X_train_full, y_train_full), (x_test, y_test) = tk.datasets.mnist.load_data()
X_test, X_train = X_train_full[:5000] / 255.0, X_train_full[5000:] / 255.0
y_test, y_train = y_train_full[:5000], y_train_full[5000:]
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (55000, 28, 28) (55000,)
# (5000, 28, 28) (5000,)

# %% [markdown]
# ## Sequential model

# %%
model = tk.models.Sequential()

model.add(tk.layers.Flatten(input_shape=[28, 28]))
model.add(tk.layers.Dense(256, activation="relu"))
model.add(tk.layers.Dense(128, activation="relu"))
model.add(tk.layers.Dense(10, activation="softmax"))

# %%
model.summary()
tk.utils.plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 235,146
# Trainable params: 235,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
inp = tk.layers.Flatten(input_shape=[28, 28])
hid1 = tk.layers.Dense(256, activation="relu")
hid2 = tk.layers.Dense(128, activation="relu")
out = tk.layers.Dense(10, activation="softmax")

model = tk.models.Sequential([inp, hid1, hid2, out])

# %%
model.summary()
tk.utils.plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               200960
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 235,146
# Trainable params: 235,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="sparse_categorical_crossentropy", optimizer="sgd", metrics=["accuracy"])
res = model.fit(X_train, y_train, epochs=20, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 1719/1719 [==============================] - 4s 2ms/step - loss: 1.0369 - accuracy: 0.7207 - val_loss: 0.3120 - val_accuracy: 0.9122
# Epoch 2/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3026 - accuracy: 0.9155 - val_loss: 0.2413 - val_accuracy: 0.9322
# Epoch 3/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2440 - accuracy: 0.9311 - val_loss: 0.2014 - val_accuracy: 0.9420
# Epoch 4/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2102 - accuracy: 0.9393 - val_loss: 0.1781 - val_accuracy: 0.9518
# Epoch 5/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.1795 - accuracy: 0.9484 - val_loss: 0.1587 - val_accuracy: 0.9560
# Epoch 6/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.1637 - accuracy: 0.9532 - val_loss: 0.1475 - val_accuracy: 0.9598
# Epoch 7/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.1422 - accuracy: 0.9597 - val_loss: 0.1320 - val_accuracy: 0.9646
# Epoch 8/20
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.1333 - accuracy: 0.9626 - val_loss: 0.1229 - val_accuracy: 0.9674
# Epoch 9/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.1132 - accuracy: 0.9677 - val_loss: 0.1165 - val_accuracy: 0.9706
# Epoch 10/20
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.1062 - accuracy: 0.9709 - val_loss: 0.1068 - val_accuracy: 0.9710
# Epoch 11/20
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.0997 - accuracy: 0.9723 - val_loss: 0.1015 - val_accuracy: 0.9726
# Epoch 12/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0935 - accuracy: 0.9734 - val_loss: 0.0996 - val_accuracy: 0.9718
# Epoch 13/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0844 - accuracy: 0.9766 - val_loss: 0.0968 - val_accuracy: 0.9736
# Epoch 14/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0760 - accuracy: 0.9791 - val_loss: 0.0915 - val_accuracy: 0.9752
# Epoch 15/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0740 - accuracy: 0.9802 - val_loss: 0.0864 - val_accuracy: 0.9746
# Epoch 16/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0679 - accuracy: 0.9814 - val_loss: 0.0845 - val_accuracy: 0.9754
# Epoch 17/20
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.0625 - accuracy: 0.9827 - val_loss: 0.0833 - val_accuracy: 0.9758
# Epoch 18/20
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.0588 - accuracy: 0.9841 - val_loss: 0.0790 - val_accuracy: 0.9772
# Epoch 19/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0560 - accuracy: 0.9847 - val_loss: 0.0804 - val_accuracy: 0.9754
# Epoch 20/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0521 - accuracy: 0.9865 - val_loss: 0.0758 - val_accuracy: 0.9776

# %%
pd.DataFrame(res.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1) 
plt.show()

# %% [markdown]
# ## Functional model

# %%
inp = tk.layers.Input(shape=[28, 28])
flat1 = tk.layers.Flatten(input_shape=[28, 28])(inp)
hid1 = tk.layers.Dense(2**14, activation="relu")(flat1)
hid2 = tk.layers.Dense(512, activation='relu')(hid1)
hid3 = tk.layers.Dense(28*28, activation='relu')(hid2)
resh = tk.layers.Reshape((28, 28))(hid3)
conc = tk.layers.Concatenate()([inp, resh])
flat2 = tk.layers.Flatten(input_shape=[28, 28])(conc)
out  = tk.layers.Dense(10, activation='softmax')(flat2)

model = tk.Model(inputs=[inp], outputs=[out] )

# %%
model.summary()
tk.utils.plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 28, 28)]     0
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 784)          0           input_1[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 16384)        12861440    flatten_4[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 512)          8389120     dense_12[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 784)          402192      dense_13[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 28, 28)       0           dense_14[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 28, 56)       0           input_1[0][0]
#                                                                  reshape[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 1568)         0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 10)           15690       flatten_5[0][0]
# ==================================================================================================
# Total params: 21,668,442
# Trainable params: 21,668,442
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(loss="sparse_categorical_crossentropy", optimizer="sgd", metrics=["accuracy"])
res = model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 85s 49ms/step - loss: 0.5823 - accuracy: 0.8594 - val_loss: 0.2898 - val_accuracy: 0.9186
# Epoch 2/10
# 1719/1719 [==============================] - 86s 50ms/step - loss: 0.2673 - accuracy: 0.9248 - val_loss: 0.2104 - val_accuracy: 0.9416
# Epoch 3/10
# 1719/1719 [==============================] - 88s 51ms/step - loss: 0.2054 - accuracy: 0.9415 - val_loss: 0.1697 - val_accuracy: 0.9554
# Epoch 4/10
# 1719/1719 [==============================] - 86s 50ms/step - loss: 0.1647 - accuracy: 0.9539 - val_loss: 0.1439 - val_accuracy: 0.9600
# Epoch 5/10
# 1719/1719 [==============================] - 85s 49ms/step - loss: 0.1349 - accuracy: 0.9613 - val_loss: 0.1261 - val_accuracy: 0.9654
# Epoch 6/10
# 1719/1719 [==============================] - 90s 52ms/step - loss: 0.1116 - accuracy: 0.9685 - val_loss: 0.1085 - val_accuracy: 0.9702
# Epoch 7/10
# 1719/1719 [==============================] - 89s 52ms/step - loss: 0.0939 - accuracy: 0.9736 - val_loss: 0.0982 - val_accuracy: 0.9736
# Epoch 8/10
# 1719/1719 [==============================] - 87s 51ms/step - loss: 0.0796 - accuracy: 0.9779 - val_loss: 0.0885 - val_accuracy: 0.9756
# Epoch 9/10
# 1719/1719 [==============================] - 87s 51ms/step - loss: 0.0684 - accuracy: 0.9813 - val_loss: 0.0876 - val_accuracy: 0.9752
# Epoch 10/10
# 1719/1719 [==============================] - 86s 50ms/step - loss: 0.0583 - accuracy: 0.9841 - val_loss: 0.0774 - val_accuracy: 0.9776

# %%
pd.DataFrame(res.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1) 
plt.show()

# %% [markdown]
# ## Credits & Links

# %% [markdown]
# https://medium.com/@hanify/sequential-api-vs-functional-api-model-in-keras-266823d7cd5e
