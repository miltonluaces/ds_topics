# %% [markdown]
# # Dealing with categorical variables

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder, OneHotEncoder 
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, Input, concatenate
from tensorflow.keras.utils import plot_model

# %%
data = pd.read_csv('D:/data/csv/breast_cancer.csv', header=None)
dataset = data.values
data.head()
# Out:
#          0          1        2      3      4    5        6           7      8  \
# 0  '40-49'  'premeno'  '15-19'  '0-2'  'yes'  '3'  'right'   'left_up'   'no'
# 1  '50-59'     'ge40'  '15-19'  '0-2'   'no'  '1'  'right'   'central'   'no'
# 2  '50-59'     'ge40'  '35-39'  '0-2'   'no'  '2'   'left'  'left_low'   'no'
# 3  '40-49'  'premeno'  '35-39'  '0-2'  'yes'  '3'  'right'  'left_low'  'yes'
# 4  '40-49'  'premeno'  '30-34'  '3-5'  'yes'  '2'   'left'  'right_up'   'no'
#
#                         9
# 0     'recurrence-events'
# 1  'no-recurrence-events'
# 2     'recurrence-events'
# 3  'no-recurrence-events'
# 4     'recurrence-events'

# %%
# load the dataset
def load_dataset(filename):
    # load the dataset as a pandas DataFrame
    data = pd.read_csv(filename, header=None)
    # retrieve numpy array
    dataset = data.values
    # split into input (X) and output (y) variables
    X = dataset[:, :-1]
    y = dataset[:,-1]
    # format all fields as string
    X = X.astype(str)
    # reshape target to be a 2d array
    y = y.reshape((len(y), 1))
    return X, y

# %%
# load the dataset
X, y = load_dataset('D:/data/csv/breast_cancer.csv')
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
# summarize
print('Train', X_train.shape, y_train.shape)
print('Test', X_test.shape, y_test.shape)
# Out:
# Train (191, 9) (191, 1)
# Test (95, 9) (95, 1)

# %% [markdown]
# ## Ordinal encoding

# %%
# prepare input data
def prepare_inputs(X_train, X_test):
    oe = OrdinalEncoder()
    oe.fit(X_train)
    X_train_enc = oe.transform(X_train)
    X_test_enc = oe.transform(X_test)
    return X_train_enc, X_test_enc

# %%
# prepare target
def prepare_targets(y_train, y_test):
    le = LabelEncoder()
    le.fit(y_train)
    y_train_enc = le.transform(y_train)
    y_test_enc = le.transform(y_test)
    return y_train_enc, y_test_enc

# %%
# prepare input data
X_train_enc, X_test_enc = prepare_inputs(X_train, X_test)
# prepare output data
y_train_enc, y_test_enc = prepare_targets(y_train, y_test)
# Out:
# C:\Program Files\Python38\lib\site-packages\sklearn\preprocessing\_label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Program Files\Python38\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ## Build the model

# %%
# define the model
model = Sequential()
model.add(Dense(10, input_dim=X_train_enc.shape[1], activation='relu', kernel_initializer='he_normal'))
model.add(Dense(1, activation='sigmoid'))
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit the keras model on the dataset
model.fit(X_train_enc, y_train_enc, epochs=100, batch_size=16, verbose=2)
# evaluate the keras model
_, accuracy = model.evaluate(X_test_enc, y_test_enc, verbose=0)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Epoch 1/100
# 12/12 - 0s - loss: 0.6949 - accuracy: 0.5497
# Epoch 2/100
# 12/12 - 0s - loss: 0.6534 - accuracy: 0.6545
# Epoch 3/100
# 12/12 - 0s - loss: 0.6374 - accuracy: 0.6806
# Epoch 4/100
# 12/12 - 0s - loss: 0.6306 - accuracy: 0.6806
# Epoch 5/100
# 12/12 - 0s - loss: 0.6218 - accuracy: 0.6911
# Epoch 6/100
# 12/12 - 0s - loss: 0.6183 - accuracy: 0.6859
# Epoch 7/100
# 12/12 - 0s - loss: 0.6122 - accuracy: 0.6963
# Epoch 8/100
# 12/12 - 0s - loss: 0.6076 - accuracy: 0.7068
# Epoch 9/100
# 12/12 - 0s - loss: 0.6029 - accuracy: 0.6963
# Epoch 10/100
# 12/12 - 0s - loss: 0.5984 - accuracy: 0.7173
# Epoch 11/100
# 12/12 - 0s - loss: 0.5941 - accuracy: 0.7382
# Epoch 12/100
# 12/12 - 0s - loss: 0.5900 - accuracy: 0.7382
# Epoch 13/100
# 12/12 - 0s - loss: 0.5874 - accuracy: 0.7382
# Epoch 14/100
# 12/12 - 0s - loss: 0.5822 - accuracy: 0.7382
# Epoch 15/100
# 12/12 - 0s - loss: 0.5807 - accuracy: 0.7382
# Epoch 16/100
# 12/12 - 0s - loss: 0.5780 - accuracy: 0.7382
# Epoch 17/100
# 12/12 - 0s - loss: 0.5726 - accuracy: 0.7435
# Epoch 18/100
# 12/12 - 0s - loss: 0.5704 - accuracy: 0.7382
# Epoch 19/100
# 12/12 - 0s - loss: 0.5676 - accuracy: 0.7382
# Epoch 20/100
# 12/12 - 0s - loss: 0.5646 - accuracy: 0.7382
# Epoch 21/100
# 12/12 - 0s - loss: 0.5641 - accuracy: 0.7382
# Epoch 22/100
# 12/12 - 0s - loss: 0.5596 - accuracy: 0.7330
# Epoch 23/100
# 12/12 - 0s - loss: 0.5581 - accuracy: 0.7330
# Epoch 24/100
# 12/12 - 0s - loss: 0.5553 - accuracy: 0.7382
# Epoch 25/100
# 12/12 - 0s - loss: 0.5527 - accuracy: 0.7382
# Epoch 26/100
# 12/12 - 0s - loss: 0.5503 - accuracy: 0.7382
# Epoch 27/100
# 12/12 - 0s - loss: 0.5507 - accuracy: 0.7330
# Epoch 28/100
# 12/12 - 0s - loss: 0.5473 - accuracy: 0.7330
# Epoch 29/100
# 12/12 - 0s - loss: 0.5433 - accuracy: 0.7435
# Epoch 30/100
# 12/12 - 0s - loss: 0.5421 - accuracy: 0.7435
# Epoch 31/100
# 12/12 - 0s - loss: 0.5407 - accuracy: 0.7487
# Epoch 32/100
# 12/12 - 0s - loss: 0.5382 - accuracy: 0.7435
# Epoch 33/100
# 12/12 - 0s - loss: 0.5369 - accuracy: 0.7487
# Epoch 34/100
# 12/12 - 0s - loss: 0.5356 - accuracy: 0.7487
# Epoch 35/100
# 12/12 - 0s - loss: 0.5339 - accuracy: 0.7487
# Epoch 36/100
# 12/12 - 0s - loss: 0.5326 - accuracy: 0.7487
# Epoch 37/100
# 12/12 - 0s - loss: 0.5315 - accuracy: 0.7435
# Epoch 38/100
# 12/12 - 0s - loss: 0.5311 - accuracy: 0.7487
# Epoch 39/100
# 12/12 - 0s - loss: 0.5273 - accuracy: 0.7539
# Epoch 40/100
# 12/12 - 0s - loss: 0.5283 - accuracy: 0.7435
# Epoch 41/100
# 12/12 - 0s - loss: 0.5290 - accuracy: 0.7592
# Epoch 42/100
# 12/12 - 0s - loss: 0.5243 - accuracy: 0.7539
# Epoch 43/100
# 12/12 - 0s - loss: 0.5230 - accuracy: 0.7539
# Epoch 44/100
# 12/12 - 0s - loss: 0.5222 - accuracy: 0.7539
# Epoch 45/100
# 12/12 - 0s - loss: 0.5208 - accuracy: 0.7539
# Epoch 46/100
# 12/12 - 0s - loss: 0.5199 - accuracy: 0.7487
# Epoch 47/100
# 12/12 - 0s - loss: 0.5203 - accuracy: 0.7487
# Epoch 48/100
# 12/12 - 0s - loss: 0.5177 - accuracy: 0.7539
# Epoch 49/100
# 12/12 - 0s - loss: 0.5175 - accuracy: 0.7539
# Epoch 50/100
# 12/12 - 0s - loss: 0.5161 - accuracy: 0.7539
# Epoch 51/100
# 12/12 - 0s - loss: 0.5165 - accuracy: 0.7592
# Epoch 52/100
# 12/12 - 0s - loss: 0.5136 - accuracy: 0.7487
# Epoch 53/100
# 12/12 - 0s - loss: 0.5126 - accuracy: 0.7539
# Epoch 54/100
# 12/12 - 0s - loss: 0.5124 - accuracy: 0.7539
# Epoch 55/100
# 12/12 - 0s - loss: 0.5103 - accuracy: 0.7592
# Epoch 56/100
# 12/12 - 0s - loss: 0.5094 - accuracy: 0.7644
# Epoch 57/100
# 12/12 - 0s - loss: 0.5086 - accuracy: 0.7644
# Epoch 58/100
# 12/12 - 0s - loss: 0.5079 - accuracy: 0.7696
# Epoch 59/100
# 12/12 - 0s - loss: 0.5064 - accuracy: 0.7749
# Epoch 60/100
# 12/12 - 0s - loss: 0.5057 - accuracy: 0.7592
# Epoch 61/100
# 12/12 - 0s - loss: 0.5046 - accuracy: 0.7696
# Epoch 62/100
# 12/12 - 0s - loss: 0.5044 - accuracy: 0.7696
# Epoch 63/100
# 12/12 - 0s - loss: 0.5036 - accuracy: 0.7749
# Epoch 64/100
# 12/12 - 0s - loss: 0.5029 - accuracy: 0.7749
# Epoch 65/100
# 12/12 - 0s - loss: 0.5025 - accuracy: 0.7696
# Epoch 66/100
# 12/12 - 0s - loss: 0.5030 - accuracy: 0.7696
# Epoch 67/100
# 12/12 - 0s - loss: 0.5006 - accuracy: 0.7696
# Epoch 68/100
# 12/12 - 0s - loss: 0.5000 - accuracy: 0.7696
# Epoch 69/100
# 12/12 - 0s - loss: 0.4985 - accuracy: 0.7696
# Epoch 70/100
# 12/12 - 0s - loss: 0.4986 - accuracy: 0.7644
# Epoch 71/100
# 12/12 - 0s - loss: 0.4975 - accuracy: 0.7696
# Epoch 72/100
# 12/12 - 0s - loss: 0.4974 - accuracy: 0.7592
# Epoch 73/100
# 12/12 - 0s - loss: 0.4951 - accuracy: 0.7644
# Epoch 74/100
# 12/12 - 0s - loss: 0.4978 - accuracy: 0.7644
# Epoch 75/100
# 12/12 - 0s - loss: 0.4946 - accuracy: 0.7644
# Epoch 76/100
# 12/12 - 0s - loss: 0.4935 - accuracy: 0.7749
# Epoch 77/100
# 12/12 - 0s - loss: 0.4946 - accuracy: 0.7749
# Epoch 78/100
# 12/12 - 0s - loss: 0.4942 - accuracy: 0.7644
# Epoch 79/100
# 12/12 - 0s - loss: 0.4927 - accuracy: 0.7749
# Epoch 80/100
# 12/12 - 0s - loss: 0.4922 - accuracy: 0.7801
# Epoch 81/100
# 12/12 - 0s - loss: 0.4932 - accuracy: 0.7801
# Epoch 82/100
# 12/12 - 0s - loss: 0.4918 - accuracy: 0.7749
# Epoch 83/100
# 12/12 - 0s - loss: 0.4902 - accuracy: 0.7644
# Epoch 84/100
# 12/12 - 0s - loss: 0.4895 - accuracy: 0.7696
# Epoch 85/100
# 12/12 - 0s - loss: 0.4902 - accuracy: 0.7749
# Epoch 86/100
# 12/12 - 0s - loss: 0.4891 - accuracy: 0.7749
# Epoch 87/100
# 12/12 - 0s - loss: 0.4884 - accuracy: 0.7801
# Epoch 88/100
# 12/12 - 0s - loss: 0.4869 - accuracy: 0.7749
# Epoch 89/100
# 12/12 - 0s - loss: 0.4884 - accuracy: 0.7853
# Epoch 90/100
# 12/12 - 0s - loss: 0.4862 - accuracy: 0.7801
# Epoch 91/100
# 12/12 - 0s - loss: 0.4845 - accuracy: 0.7696
# Epoch 92/100
# 12/12 - 0s - loss: 0.4840 - accuracy: 0.7696
# Epoch 93/100
# 12/12 - 0s - loss: 0.4849 - accuracy: 0.7801
# Epoch 94/100
# 12/12 - 0s - loss: 0.4846 - accuracy: 0.7644
# Epoch 95/100
# 12/12 - 0s - loss: 0.4839 - accuracy: 0.7644
# Epoch 96/100
# 12/12 - 0s - loss: 0.4836 - accuracy: 0.7853
# Epoch 97/100
# 12/12 - 0s - loss: 0.4823 - accuracy: 0.7906
# Epoch 98/100
# 12/12 - 0s - loss: 0.4813 - accuracy: 0.7749
# Epoch 99/100
# 12/12 - 0s - loss: 0.4805 - accuracy: 0.7696
# Epoch 100/100
# 12/12 - 0s - loss: 0.4810 - accuracy: 0.7749
# Accuracy: 68.42

# %% [markdown]
# ## One hot encoding

# %%
# prepare input data
def prepare_inputs(X_train, X_test):
    ohe = OneHotEncoder()
    ohe.fit(X_train)
    X_train_enc = ohe.transform(X_train)
    X_test_enc = ohe.transform(X_test)
    return X_train_enc, X_test_enc

# prepare target
def prepare_targets(y_train, y_test):
    le = LabelEncoder()
    le.fit(y_train)
    y_train_enc = le.transform(y_train)
    y_test_enc = le.transform(y_test)
    return y_train_enc, y_test_enc

# prepare input data
X_train_enc, X_test_enc = prepare_inputs(X_train, X_test)
# prepare output data
y_train_enc, y_test_enc = prepare_targets(y_train, y_test)
# define the  model
model = Sequential()
model.add(Dense(10, input_dim=X_train_enc.shape[1], activation='relu', kernel_initializer='he_normal'))
model.add(Dense(1, activation='sigmoid'))
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit the keras model on the dataset
model.fit(X_train_enc, y_train_enc, epochs=100, batch_size=16, verbose=2)
# evaluate the keras model
_, accuracy = model.evaluate(X_test_enc, y_test_enc, verbose=0)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# C:\Program Files\Python38\lib\site-packages\sklearn\preprocessing\_label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Program Files\Python38\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Epoch 1/100
# 12/12 - 0s - loss: 0.7595 - accuracy: 0.4503
# Epoch 2/100
# 12/12 - 0s - loss: 0.7045 - accuracy: 0.5183
# Epoch 3/100
# 12/12 - 0s - loss: 0.6570 - accuracy: 0.5916
# Epoch 4/100
# 12/12 - 0s - loss: 0.6267 - accuracy: 0.6230
# Epoch 5/100
# 12/12 - 0s - loss: 0.6006 - accuracy: 0.6754
# Epoch 6/100
# 12/12 - 0s - loss: 0.5821 - accuracy: 0.7016
# Epoch 7/100
# 12/12 - 0s - loss: 0.5688 - accuracy: 0.7120
# Epoch 8/100
# 12/12 - 0s - loss: 0.5585 - accuracy: 0.7277
# Epoch 9/100
# 12/12 - 0s - loss: 0.5498 - accuracy: 0.7330
# Epoch 10/100
# 12/12 - 0s - loss: 0.5430 - accuracy: 0.7382
# Epoch 11/100
# 12/12 - 0s - loss: 0.5375 - accuracy: 0.7487
# Epoch 12/100
# 12/12 - 0s - loss: 0.5332 - accuracy: 0.7539
# Epoch 13/100
# 12/12 - 0s - loss: 0.5266 - accuracy: 0.7644
# Epoch 14/100
# 12/12 - 0s - loss: 0.5229 - accuracy: 0.7749
# Epoch 15/100
# 12/12 - 0s - loss: 0.5164 - accuracy: 0.7749
# Epoch 16/100
# 12/12 - 0s - loss: 0.5126 - accuracy: 0.7749
# Epoch 17/100
# 12/12 - 0s - loss: 0.5092 - accuracy: 0.7749
# Epoch 18/100
# 12/12 - 0s - loss: 0.5053 - accuracy: 0.7801
# Epoch 19/100
# 12/12 - 0s - loss: 0.5009 - accuracy: 0.7749
# Epoch 20/100
# 12/12 - 0s - loss: 0.4979 - accuracy: 0.7749
# Epoch 21/100
# 12/12 - 0s - loss: 0.4935 - accuracy: 0.7696
# Epoch 22/100
# 12/12 - 0s - loss: 0.4903 - accuracy: 0.7749
# Epoch 23/100
# 12/12 - 0s - loss: 0.4873 - accuracy: 0.7749
# Epoch 24/100
# 12/12 - 0s - loss: 0.4847 - accuracy: 0.7906
# Epoch 25/100
# 12/12 - 0s - loss: 0.4810 - accuracy: 0.7906
# Epoch 26/100
# 12/12 - 0s - loss: 0.4784 - accuracy: 0.7801
# Epoch 27/100
# 12/12 - 0s - loss: 0.4757 - accuracy: 0.7853
# Epoch 28/100
# 12/12 - 0s - loss: 0.4722 - accuracy: 0.7801
# Epoch 29/100
# 12/12 - 0s - loss: 0.4703 - accuracy: 0.7906
# Epoch 30/100
# 12/12 - 0s - loss: 0.4664 - accuracy: 0.7958
# Epoch 31/100
# 12/12 - 0s - loss: 0.4639 - accuracy: 0.7958
# Epoch 32/100
# 12/12 - 0s - loss: 0.4611 - accuracy: 0.7958
# Epoch 33/100
# 12/12 - 0s - loss: 0.4580 - accuracy: 0.7958
# Epoch 34/100
# 12/12 - 0s - loss: 0.4558 - accuracy: 0.7958
# Epoch 35/100
# 12/12 - 0s - loss: 0.4547 - accuracy: 0.7958
# Epoch 36/100
# 12/12 - 0s - loss: 0.4512 - accuracy: 0.7958
# Epoch 37/100
# 12/12 - 0s - loss: 0.4497 - accuracy: 0.7958
# Epoch 38/100
# 12/12 - 0s - loss: 0.4475 - accuracy: 0.7958
# Epoch 39/100
# 12/12 - 0s - loss: 0.4447 - accuracy: 0.7958
# Epoch 40/100
# 12/12 - 0s - loss: 0.4425 - accuracy: 0.7958
# Epoch 41/100
# 12/12 - 0s - loss: 0.4420 - accuracy: 0.8010
# Epoch 42/100
# 12/12 - 0s - loss: 0.4393 - accuracy: 0.8010
# Epoch 43/100
# 12/12 - 0s - loss: 0.4371 - accuracy: 0.8010
# Epoch 44/100
# 12/12 - 0s - loss: 0.4348 - accuracy: 0.8010
# Epoch 45/100
# 12/12 - 0s - loss: 0.4337 - accuracy: 0.8063
# Epoch 46/100
# 12/12 - 0s - loss: 0.4312 - accuracy: 0.8010
# Epoch 47/100
# 12/12 - 0s - loss: 0.4297 - accuracy: 0.8010
# Epoch 48/100
# 12/12 - 0s - loss: 0.4286 - accuracy: 0.8010
# Epoch 49/100
# 12/12 - 0s - loss: 0.4252 - accuracy: 0.8063
# Epoch 50/100
# 12/12 - 0s - loss: 0.4234 - accuracy: 0.8010
# Epoch 51/100
# 12/12 - 0s - loss: 0.4222 - accuracy: 0.8010
# Epoch 52/100
# 12/12 - 0s - loss: 0.4204 - accuracy: 0.8010
# Epoch 53/100
# 12/12 - 0s - loss: 0.4189 - accuracy: 0.8010
# Epoch 54/100
# 12/12 - 0s - loss: 0.4162 - accuracy: 0.8063
# Epoch 55/100
# 12/12 - 0s - loss: 0.4152 - accuracy: 0.8010
# Epoch 56/100
# 12/12 - 0s - loss: 0.4128 - accuracy: 0.8010
# Epoch 57/100
# 12/12 - 0s - loss: 0.4120 - accuracy: 0.8010
# Epoch 58/100
# 12/12 - 0s - loss: 0.4099 - accuracy: 0.8010
# Epoch 59/100
# 12/12 - 0s - loss: 0.4090 - accuracy: 0.8063
# Epoch 60/100
# 12/12 - 0s - loss: 0.4072 - accuracy: 0.8063
# Epoch 61/100
# 12/12 - 0s - loss: 0.4034 - accuracy: 0.8063
# Epoch 62/100
# 12/12 - 0s - loss: 0.4028 - accuracy: 0.8063
# Epoch 63/100
# 12/12 - 0s - loss: 0.4013 - accuracy: 0.8063
# Epoch 64/100
# 12/12 - 0s - loss: 0.3996 - accuracy: 0.8010
# Epoch 65/100
# 12/12 - 0s - loss: 0.3979 - accuracy: 0.8115
# Epoch 66/100
# 12/12 - 0s - loss: 0.3967 - accuracy: 0.8168
# Epoch 67/100
# 12/12 - 0s - loss: 0.3956 - accuracy: 0.8115
# Epoch 68/100
# 12/12 - 0s - loss: 0.3949 - accuracy: 0.8063
# Epoch 69/100
# 12/12 - 0s - loss: 0.3930 - accuracy: 0.8063
# Epoch 70/100
# 12/12 - 0s - loss: 0.3902 - accuracy: 0.8115
# Epoch 71/100
# 12/12 - 0s - loss: 0.3889 - accuracy: 0.8115
# Epoch 72/100
# 12/12 - 0s - loss: 0.3881 - accuracy: 0.8115
# Epoch 73/100
# 12/12 - 0s - loss: 0.3869 - accuracy: 0.8063
# Epoch 74/100
# 12/12 - 0s - loss: 0.3845 - accuracy: 0.8063
# Epoch 75/100
# 12/12 - 0s - loss: 0.3839 - accuracy: 0.8115
# Epoch 76/100
# 12/12 - 0s - loss: 0.3827 - accuracy: 0.8220
# Epoch 77/100
# 12/12 - 0s - loss: 0.3817 - accuracy: 0.8220
# Epoch 78/100
# 12/12 - 0s - loss: 0.3804 - accuracy: 0.8115
# Epoch 79/100
# 12/12 - 0s - loss: 0.3781 - accuracy: 0.8115
# Epoch 80/100
# 12/12 - 0s - loss: 0.3772 - accuracy: 0.8115
# Epoch 81/100
# 12/12 - 0s - loss: 0.3749 - accuracy: 0.8115
# Epoch 82/100
# 12/12 - 0s - loss: 0.3749 - accuracy: 0.8272
# Epoch 83/100
# 12/12 - 0s - loss: 0.3723 - accuracy: 0.8272
# Epoch 84/100
# 12/12 - 0s - loss: 0.3720 - accuracy: 0.8220
# Epoch 85/100
# 12/12 - 0s - loss: 0.3704 - accuracy: 0.8325
# Epoch 86/100
# 12/12 - 0s - loss: 0.3695 - accuracy: 0.8377
# Epoch 87/100
# 12/12 - 0s - loss: 0.3682 - accuracy: 0.8325
# Epoch 88/100
# 12/12 - 0s - loss: 0.3673 - accuracy: 0.8325
# Epoch 89/100
# 12/12 - 0s - loss: 0.3656 - accuracy: 0.8377
# Epoch 90/100
# 12/12 - 0s - loss: 0.3647 - accuracy: 0.8377
# Epoch 91/100
# 12/12 - 0s - loss: 0.3627 - accuracy: 0.8377
# Epoch 92/100
# 12/12 - 0s - loss: 0.3614 - accuracy: 0.8377
# Epoch 93/100
# 12/12 - 0s - loss: 0.3610 - accuracy: 0.8325
# Epoch 94/100
# 12/12 - 0s - loss: 0.3583 - accuracy: 0.8377
# Epoch 95/100
# 12/12 - 0s - loss: 0.3582 - accuracy: 0.8429
# Epoch 96/100
# 12/12 - 0s - loss: 0.3560 - accuracy: 0.8429
# Epoch 97/100
# 12/12 - 0s - loss: 0.3561 - accuracy: 0.8429
# Epoch 98/100
# 12/12 - 0s - loss: 0.3539 - accuracy: 0.8429
# Epoch 99/100
# 12/12 - 0s - loss: 0.3528 - accuracy: 0.8429
# Epoch 100/100
# 12/12 - 0s - loss: 0.3514 - accuracy: 0.8429
# Accuracy: 69.47

# %% [markdown]
# ## Learned Embeddings

# %%
# prepare input data
def prepare_inputs(X_train, X_test):
    X_train_enc, X_test_enc = list(), list()
    # label encode each column
    for i in range(X_train.shape[1]):
        le = LabelEncoder()
        le.fit(X_train[:, i])
        # encode
        train_enc = le.transform(X_train[:, i])
        test_enc = le.transform(X_test[:, i])
        # store
        X_train_enc.append(train_enc)
        X_test_enc.append(test_enc)
        return X_train_enc, X_test_enc

# prepare target
def prepare_targets(y_train, y_test):
    le = LabelEncoder()
    le.fit(y_train)
    y_train_enc = le.transform(y_train)
    y_test_enc = le.transform(y_test)
    return y_train_enc, y_test_enc

# %%
X_train.shape, X_test.shape
# Out:
# ((191, 9), (95, 9))

# %%
# prepare input data
X_train_enc, X_test_enc = prepare_inputs(X_train, X_test)
print(len(X_train_enc), len(X_test_enc)) 
# prepare output data
y_train_enc, y_test_enc = prepare_targets(y_train, y_test)
print(len(y_train_enc), len(y_test_enc))
# Out:
# 1 1
# 191 95

# %%
# make output 3d
y_train_enc = y_train_enc.reshape((len(y_train_enc), 1, 1))
y_test_enc = y_test_enc.reshape((len(y_test_enc), 1, 1))

# prepare each input head
in_layers = list()
em_layers = list()
for i in range(len(X_train_enc)):
    # calculate the number of unique inputs
    n_labels = len(np.unique(X_train_enc[i]))
    # define input layer
    in_layer = Input(shape=(1,))
    # define embedding layer
    em_layer = Embedding(n_labels, 10)(in_layer)
    # store layers
    in_layers.append(in_layer)
    em_layers.append(em_layer)
# Out:
# 1

# %%
# concat all embeddings
merge = concatenate(em_layers)
dense = Dense(10, activation='relu', kernel_initializer='he_normal')(merge)
output = Dense(1, activation='sigmoid')(dense)
model = Model(inputs=in_layers, outputs=output)
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# plot graph
plot_model(model, show_shapes=True, to_file='embeddings.png')
# fit the keras model on the dataset
model.fit(X_train_enc, y_train_enc, epochs=20, batch_size=16, verbose=2)
# evaluate the keras model
_, accuracy = model.evaluate(X_test_enc, y_test_enc, verbose=0)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-ee9fbd7cb9cd> in <module>
#      20     em_layers.append(em_layer)
#      21 # concat all embeddings
# ---> 22 merge = concatenate(em_layers)
#      23 dense = Dense(10, activation='relu', kernel_initializer='he_normal')(merge)
#      24 output = Dense(1, activation='sigmoid')(dense)
#
# C:\Program Files\Python38\lib\site-packages\tensorflow\python\keras\layers\merge.py in concatenate(inputs, axis, **kwargs)
#     925       A tensor, the concatenation of the inputs alongside axis `axis`.
#     926   """
# --> 927   return Concatenate(axis=axis, **kwargs)(inputs)
#     928
#     929
#
# C:\Program Files\Python38\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#     894           # Build layer if applicable (if the `build` method has been
#     895           # overridden).
# --> 896           self._maybe_build(inputs)
#     897           cast_inputs = self._maybe_cast_inputs(inputs)
#     898
#
# C:\Program Files\Python38\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in _maybe_build(self, inputs)
#    2401         # operations.
#    2402         with tf_utils.maybe_init_scope(self):
# -> 2403           self.build(input_shapes)  # pylint:disable=not-callable
#    2404       # We must set also ensure that the layer is marked as built, and the build
#    2405       # shape is stored since user defined build functions may not be calling
#
# C:\Program Files\Python38\lib\site-packages\tensorflow\python\keras\utils\tf_utils.py in wrapper(instance, input_shape)
#     314     if input_shape is not None:
#     315       input_shape = convert_shapes(input_shape, to_tuples=True)
# --> 316     output_shape = fn(instance, input_shape)
#     317     # Return shapes from `fn` as TensorShapes.
#     318     if output_shape is not None:
#
# C:\Program Files\Python38\lib\site-packages\tensorflow\python\keras\layers\merge.py in build(self, input_shape)
#     491     # Used purely for shape validation.
#     492     if not isinstance(input_shape[0], tuple) or len(input_shape) < 2:
# --> 493       raise ValueError('A `Concatenate` layer should be called '
#     494                        'on a list of at least 2 inputs')
#     495     if all(shape is None for shape in input_shape):
#
# ValueError: A `Concatenate` layer should be called on a list of at least 2 inputs

# %% [markdown]
# ## Credits & Links

# %% [markdown]
# https://mc.ai/3-ways-to-encode-categorical-variables-for-deep-learning/
# https://towardsdatascience.com/deep-embeddings-for-categorical-variables-cat2vec-b05c8ab63ac0
