# %% [markdown]
# # Rank correlation

# %% [markdown]
# ## Imports

# %%
from scipy.stats import spearmanr
from scipy.stats import kendalltau
from numpy.random import rand
from numpy.random import seed
import matplotlib.pyplot as plt
seed(1)

# %% [markdown]
# ### Simple example of correlation

# %%
a = [1,2,3,4,5]
b = [5,6,7,8,7]
rc = spearmanr(a,b)
print('corr_coeff = ', '{0:.2f}'.format(rc[0]))
print('pVal = ', '{0:.2f}'.format(rc[1]))
# Out:
# corr_coeff =  0.82
# pVal =  0.09

# %% [markdown]
# ### Load data

# %%
data1 = rand(1000) * 20
data2 = data1 + (rand(1000) * 10)

plt.scatter(data1, data2);

# %% [markdown]
# ### Spearman's correlation
# Ordinal scale: r corr on ranks

# %%
coef, p = spearmanr(data1, data2)
print('\nSpearman correlation')
print('corr_coeff = ', '{0:.2f}'.format(coef))
print('pVal = ', '{0:.2f}'.format(p))
# Out:
# Spearman correlation
# corr_coeff =  0.89
# pVal =  0.00

# %% [markdown]
# ### Kendall's correlation
# Normalized score of the correspondant ranks

# %%
coef, p = kendalltau(data1, data2)
print('\nKendall correlation')
print('corr_coeff = ', '{0:.2f}'.format(coef))
print('pVal = ', '{0:.2f}'.format(p))
# Out:
# Kendall correlation
# corr_coeff =  0.70
# pVal =  0.00

# %% [markdown]
# ## Credits & Links
