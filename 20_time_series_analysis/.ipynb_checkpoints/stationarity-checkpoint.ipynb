# %% [markdown]
# # Stationarity

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas import read_csv
from statsmodels.tsa.stattools import adfuller
# %pylab inline
figsize(12,6)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Program Files\Python38\lib\site-packages\IPython\core\magics\pylab.py:159: UserWarning: pylab import has clobbered these variables: ['split']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %% [markdown]
# Stationary time series

# %%
fb = pd.read_csv('D:/data/csv/female_births.csv', header=0, index_col=0)
fb.plot();

# %% [markdown]
# Non-stationary time series

# %%
ap = pd.read_csv('D:/data/csv/airline_passengers.csv', header=0, index_col=0)
ap.plot();

# %%
def ts_dist(ts, nsplit):
    figsize(20,10)
    split = (int)(ts.shape[0]/nsplit)
    start=0
    Ts = []
    for i in range(nsplit):
        end=start+split
        Ts.append(ts[start:end])
        start=end+1
        end=start+split
    for ts in Ts:
        sns.distplot(ts);

# %%
ts_dist(ts=fb, nsplit=3)

# %%
ts_dist(ts=ap, nsplit=3)

# %% [markdown]
# ### Dickey-Fuller test

# %%
X = fb.values
res = adfuller(X)
print('p-value:\t' , res[1])
# Out:
# p-value:	 5.243412990149865e-05

# %% [markdown]
# ### Credits & Links

# %% [markdown]
# https://machinelearningmastery.com/time-series-data-stationary-python/
